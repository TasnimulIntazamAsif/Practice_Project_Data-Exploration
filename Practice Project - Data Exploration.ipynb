# %% [markdown]
# <center><h1>Practice Project: Data Exploration</h1></center>

# %% [markdown]
# ## Importing Necessary Libraries for Data Exploration

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set() # Apply the default seaborn theme, scaling, and color palette

import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## About Dataset
# This classic dataset contains the prices and other attributes of almost 54,000 diamonds. It's a great dataset for beginners learning to work with data analysis and visualization.
#
# ### Attributes
#
# * $price =$ price in US dollars (\\$326--\\$18,823)
# * $carat =$ weight of the diamond (0.2--5.01)
# * $cut =$ quality of the cut (Fair, Good, Very Good, Premium, Ideal)
# * $color =$ diamond colour, from J (worst) to D (best)
# * $clarity =$ a measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
# * $x =$ length in mm (0--10.74)
# * $y =$ width in mm (0--58.9)
# * $z =$ depth in mm (0--31.8)
# * $depth =$ total depth percentage = $z / mean(x, y) = 2 * z / (x + y) (43--79)$
# * $table =$ width of top of diamond relative to widest point (43--95)

# %% [markdown]
# ## Load the Dataset

# %%
diamonds = sns.load_dataset("diamonds")  # Loaded in a Pandas DataFrame
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# ## 1.0 Variable Identification

# %%
diamonds.dtypes
# Out:
# carat       float64
# cut        category
# color      category
# clarity    category
# depth       float64
# table       float64
# price         int64
# x           float64
# y           float64
# z           float64
# dtype: object

# %%
diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %% [markdown]
# ## 2.0 Univariate Analysis

# %% [markdown]
# ### 2.1 For continuous variables: mean, median, mode, min, max, histograms (distribution), and boxplots

# %%
diamonds.describe(include=['category'])
# Out:
#           cut  color clarity
# count   53940  53940   53940
# unique      5      7       8
# top     Ideal      G     SI1
# freq    21551  11292   13065

# %%
mean = diamonds['carat'].mean()
median = diamonds['carat'].median()
mode = diamonds['carat'].mode().values[0]
min_val = diamonds['carat'].min()
max_val = diamonds['carat'].max()

print(f'Mean: {mean:.2f}')
print(f'Median: {median:.2f}')
print(f'Mode: {mode:.2f}')
print(f'Min: {min_val:.2f}')
print(f'Max: {max_val:.2f}')

plt.hist(diamonds['carat'])
plt.axvline(mean, color='r', linestyle='dashed', linewidth=2, label=f'Mean: {mean:.2f}')
plt.axvline(median, color='g', linestyle='dashed', linewidth=2, label=f'Median: {median:.2f}')
plt.axvline(mode, color='b', linestyle='dashed', linewidth=2, label=f'Mode: {mode:.2f}')
plt.legend(loc='upper right')
plt.show()
# Out:
# Mean: 0.80
# Median: 0.70
# Mode: 0.30
# Min: 0.20
# Max: 5.01

# %% [markdown]
# We can see that mean is to the right of median and mode. mode or the peek of our distribution is 0.3 which means it is the most occured value or dimonds with a carat of 0.3. we can Also see the the median is less the the mean which means that ouliers exist to the right of the mean and the distribution is right skewed. In order to identify the outliers let's use a box plot.

# %%
import seaborn as sns

mean = diamonds['carat'].mean()
median = diamonds['carat'].median()
mode = diamonds['carat'].mode().values[0]

sns.boxplot(x='carat', data=diamonds)
plt.title(f'Boxplot of Carat (Mean: {mean:.2f}, Median: {median:.2f}, Mode: {mode:.2f})')
plt.show()

# %% [markdown]
# we can see that 50% of the data points lies within caret of 0.5 and 0.90 and both the quartiels are pretty evenly spred out also, the median is 0.70. now we can see that byoond 1.49 which is the upper tail alot of the outliers exists. Also we know that the mode is 0.30 which is less then Q1 thus verifying the skewness of the dataset.

# %%
mean_depth = diamonds['depth'].mean()
median_depth = diamonds['depth'].median()
mode_depth = diamonds['depth'].mode().values[0]

plt.hist(diamonds['depth'], bins=10, alpha=0.7, color='blue', edgecolor='black')
plt.axvline(mean_depth, color='r', linestyle='dashed', linewidth=2, label=f'Mean: {mean_depth:.2f}')
plt.title(f'Histogram of Depth (Mean: {mean_depth:.2f})')
plt.legend(loc='upper right')
plt.show()

plt.hist(diamonds['depth'], bins=10, alpha=0.7, color='blue', edgecolor='black')
plt.axvline(median_depth, color='g', linestyle='dashed', linewidth=2, label=f'Median: {median_depth:.2f}')
plt.title(f'Histogram of Depth (Median: {median_depth:.2f})')
plt.legend(loc='upper right')
plt.show()

plt.hist(diamonds['depth'], bins=10, alpha=0.7, color='blue', edgecolor='black')
plt.axvline(mode_depth, color='b', linestyle='dashed', linewidth=2, label=f'Mode: {mode_depth:.2f}')
plt.title(f'Histogram of Depth (Mode: {mode_depth:.2f})')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# Mean of Depth: 61.75
# Median of Depth: 61.80
# Mode of Depth: 62.00
#
# we can see most of the data is at the centered and all of the central tendecies are pretty close thus depth uniformly distributed. (most things in nature are)

# %%
mean_price = diamonds['price'].mean()
median_price = diamonds['price'].median()
mode_price = diamonds['price'].mode().values[0]

plt.figure(figsize=(10,6))
plt.hist(diamonds['price'], bins=50, alpha=0.7, color='blue', edgecolor='black')
plt.axvline(mean_price, color='r', linestyle='dashed', linewidth=2, label=f'Mean: {mean_price:.2f}')
plt.axvline(median_price, color='g', linestyle='dashed', linewidth=2, label=f'Median: {median_price:.2f}')
plt.axvline(mode_price, color='b', linestyle='dashed', linewidth=2, label=f'Mode: {mode_price:.2f}')
plt.title(f'Histogram of Price (Mean: {mean_price:.2f}, Median: {median_price:.2f}, Mode: {mode_price:.2f})')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# Mean of Price: 3932.80
# Median of Price: 2401.00
# Mode of Price: 605.00
#
# We can see that price is exponentially distributed which indicates as price get's higher dimonds get rare'r which makes sense

# %%
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
diamonds.describe(include=['category'])
# Out:
#           cut  color clarity
# count   53940  53940   53940
# unique      5      7       8
# top     Ideal      G     SI1
# freq    21551  11292   13065

# %% [markdown]
# ### 2.2 For categorical variables: frequency table, count plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Convert categorical columns to string type
for column in ['cut', 'color', 'clarity']:
    diamonds[column] = diamonds[column].astype(str)

# Function to create countplot and display mean, median, mode
def create_countplot_with_stats(column_name, title):
    colors = sns.color_palette("husl", len(diamonds[column_name].unique()))
    plt.figure(figsize=(8, 6))
    sns.countplot(x=column_name, data=diamonds, palette=colors)
    plt.title(title)
    plt.xlabel(column_name.capitalize())
    plt.ylabel("Count")
    plt.show()


    print(f"Statistics for {column_name.capitalize()}:")
    # Mean, Median not applicable for categorical data
    # Mode is displayed
    mode = diamonds[column_name].mode()[0]
    print(f"  Mode(peak of distribution or highest occurence): {mode}")
    print("-" * 20)  # Separator

# Generate count plots and statistics
create_countplot_with_stats('cut', 'Count of Diamonds by Cut')
create_countplot_with_stats('color', 'Count of Diamonds by Color')
create_countplot_with_stats('clarity', 'Count of Diamonds by Clarity')
# Out:
# Statistics for Cut:
#   Mode(peak of distribution or highest occurence): Ideal
# --------------------
# Statistics for Color:
#   Mode(peak of distribution or highest occurence): G
# --------------------
# Statistics for Clarity:
#   Mode(peak of distribution or highest occurence): SI1
# --------------------

# %% [markdown]
# ## 3.0 Bi-variate Analysis

# %% [markdown]
# ### 3.1 Continuous \& Continuous: scatter plots

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select only numerical features for the pairplot
numerical_diamonds = diamonds.select_dtypes(include=np.number)

# Create the pairplot with a specified color palette and background color
sns.set_style("whitegrid")
sns.pairplot(numerical_diamonds, palette="husl")
plt.suptitle("Scatter Plots for Numerical Variables in Diamonds Dataset", y=1.02)  # Add title above the plots
plt.show()

# %% [markdown]
# This section explores the relationships between continuous variables in the diamonds dataset using scatter plots.

# %% [markdown]
# ### 3.2 Categorical & Categorical: stacked column chart

# %%
import matplotlib.pyplot as plt

# Create a new dataframe for the stacked column chart
stacked_data = diamonds.groupby(['cut', 'color']).size().unstack()
stacked_data.plot(kind='bar', stacked=True)
plt.title('Stacked Column Chart of Cut vs Color')
plt.show()

stacked_data = diamonds.groupby(['cut', 'clarity']).size().unstack()
stacked_data.plot(kind='bar', stacked=True)
plt.title('Stacked Column Chart of Cut vs Clarity')
plt.show()

stacked_data = diamonds.groupby(['color', 'clarity']).size().unstack()
stacked_data.plot(kind='bar', stacked=True)
plt.title('Stacked Column Chart of Color vs Clarity')
plt.show()

# %% [markdown]
#  This section explores the relationships between categorical variables in the diamonds dataset using stacked column charts.

# %% [markdown]
# ### 3.3 Categorical & Continuous: boxplots

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create box plots for cut vs carat, depth, table, price, x, y, z
for col in ['carat', 'depth', 'table', 'price', 'x', 'y', 'z']:
    plt.figure(figsize=(10,6))
    sns.boxplot(x='cut', y=col, data=diamonds)
    plt.title(f'Boxplot of {col} vs Cut')
    plt.show()

# Create box plots for color vs carat, depth, table, price, x, y, z
for col in ['carat', 'depth', 'table', 'price', 'x', 'y', 'z']:
    plt.figure(figsize=(10,6))
    sns.boxplot(x='color', y=col, data=diamonds)
    plt.title(f'Boxplot of {col} vs Color')
    plt.show()

# %% [markdown]
# ### 3.4 Correlation Analysis: correlation matrix

# %%
correlation_matrix = diamonds.select_dtypes(include=['int64', 'float64']).corr()
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', mask=mask, square=True)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# The correlation matrix analysis provides insights into the relationships between numerical variables in the dataset. It helps identify strong correlations between variables, which can be useful in feature engineering and model selection.

# %% [markdown]
# ## 4.0 Missing Value Analysis

# %%
diamonds.isna().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %% [markdown]
# ## 5.0 Outlier Analysis

# %%
for col in diamonds.select_dtypes(include=['int64', 'float64']).columns:
    plt.figure(figsize=(10,6))
    sns.boxplot(x=diamonds[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %% [markdown]
# The outlier analysis is crucial in identifying unusual patterns or data points that do not conform to the expected norm. This analysis helps in understanding the distribution of the data and can be useful in data preprocessing and feature engineering.

# %% [markdown]
# ## 6.0 Class Imbalance Analysis
#
# **Note:** This is not a classification problem. Here the target variable is $price$. You can just explore the frequency table of some categorical variables.

# %%
diamonds["cut"].value_counts()
# Out:
# cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: count, dtype: int64
